# %%
import matplotlib.pyplot as plt 
import pandas as pd   
data = {     
    'year': [2008,2012,2016,2018,2020,2021,2022],     
    'attendees':[112,321,792,839,560,1012,1433],     
    'average':[24,43,31,29,33,42,32] }  
df = pd.DataFrame(data)  
#print dataFrame(data) 
#print dataFrames first 5 rows 
#print(df.head())  
#print dataFrame(data) 
#print dataFrames last 5 rows 
#print(df.tail())  
#print(df.shape)  
# find typer i tabel, giver et overblik 
#print(df.info()) 
#print(df.type) 
#print(df.dtypes)  
#se colonnen average 
print(df['average'])
get_columns=['year', 'average'] 
sub_dataset_df=df[get_columns] 
print(sub_dataset_df)
# Out:
# 0    24
# 1    43
# 2    31
# 3    29
# 4    33
# 5    42
# 6    32
# Name: average, dtype: int64
#    year  average
# 0  2008       24
# 1  2012       43
# 2  2016       31
# 3  2018       29
# 4  2020       33
# 5  2021       42
# 6  2022       32

# %%
print(df.query( "year>2013" ))

# %%
df.info()

# %%
plt.plot(df['year'],df['attendees'])
plt.title('Attendees yearly')
plt.xlabel('Year')
plt.ylabel('Attendees')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
